# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/maria/Documents/UFAL/Ciencia de dados/Projeto/data/APOSENTADOS_112020_FULL.csv',low_memory=False, error_bad_lines=False, sep=';')

#Tratamento dos dados
#Drop colunas que não vão ser usadas
aposentados = df.drop(['Nome', 'CPF', 'Matricula', 'Sigla Orgao', 'Orgao vinculacao', 'Padrao',
        'Referencia', 'Nivel', 'Fund legal aposentadoria', 'Portaria aposentadoria'], axis=1)

# Tirando datas vazias
aposentados.drop(aposentados[aposentados['Dt ocorrencia inatividade'] == '        '].index, inplace = True)
aposentados.drop(aposentados[aposentados['Dt ingresso servico publico'] == '        '].index, inplace = True)

# Transformar data Dt ocorrencia inatividade; Dt ingresso servico publico; em tipo date %d%m%Y
aposentados['Dt ocorrencia inatividade'] = pd.to_datetime(aposentados['Dt ocorrencia inatividade'],format="%d%m%Y")
aposentados['Dt ingresso servico publico'] = pd.to_datetime(aposentados['Dt ingresso servico publico'],format="%d%m%Y")
# Out:
# b'Skipping line 2244: expected 18 fields, saw 19\nSkipping line 21668: expected 18 fields, saw 19\nSkipping line 27415: expected 18 fields, saw 19\nSkipping line 31601: expected 18 fields, saw 19\nSkipping line 31615: expected 18 fields, saw 19\nSkipping line 31628: expected 18 fields, saw 19\nSkipping line 31651: expected 18 fields, saw 19\nSkipping line 31652: expected 18 fields, saw 19\nSkipping line 31661: expected 18 fields, saw 19\nSkipping line 31685: expected 18 fields, saw 19\nSkipping line 31704: expected 18 fields, saw 19\nSkipping line 31722: expected 18 fields, saw 19\nSkipping line 32853: expected 18 fields, saw 19\nSkipping line 34671: expected 18 fields, saw 19\nSkipping line 35164: expected 18 fields, saw 19\nSkipping line 35252: expected 18 fields, saw 19\nSkipping line 35697: expected 18 fields, saw 19\nSkipping line 35701: expected 18 fields, saw 19\nSkipping line 36267: expected 18 fields, saw 19\nSkipping line 36523: expected 18 fields, saw 19\nSkipping line 36613: expected 18 fields, saw 19\nSkipping line 36684: expected 18 fields, saw 19\nSkipping line 43899: expected 18 fields, saw 19\nSkipping line 48189: expected 18 fields, saw 19\nSkipping line 48458: expected 18 fields, saw 19\nSkipping line 48461: expected 18 fields, saw 19\nSkipping line 48584: expected 18 fields, saw 19\nSkipping line 48605: expected 18 fields, saw 19\nSkipping line 49502: expected 18 fields, saw 19\nSkipping line 50188: expected 18 fields, saw 19\nSkipping line 56837: expected 18 fields, saw 19\nSkipping line 85331: expected 18 fields, saw 19\nSkipping line 85347: expected 18 fields, saw 19\nSkipping line 85348: expected 18 fields, saw 19\nSkipping line 85358: expected 18 fields, saw 19\nSkipping line 88246: expected 18 fields, saw 19\nSkipping line 88733: expected 18 fields, saw 19\nSkipping line 89504: expected 18 fields, saw 19\nSkipping line 94219: expected 18 fields, saw 19\nSkipping line 95197: expected 18 fields, saw 19\nSkipping line 95303: expected 18 fields, saw 19\nSkipping line 95588: expected 18 fields, saw 19\nSkipping line 100448: expected 18 fields, saw 19\nSkipping line 105811: expected 18 fields, saw 19\nSkipping line 106640: expected 18 fields, saw 19\nSkipping line 111496: expected 18 fields, saw 19\nSkipping line 111979: expected 18 fields, saw 19\nSkipping line 123084: expected 18 fields, saw 19\nSkipping line 124639: expected 18 fields, saw 19\nSkipping line 127810: expected 18 fields, saw 19\nSkipping line 129147: expected 18 fields, saw 19\nSkipping line 171201: expected 18 fields, saw 19\nSkipping line 172989: expected 18 fields, saw 20\nSkipping line 173011: expected 18 fields, saw 19\nSkipping line 174685: expected 18 fields, saw 19\nSkipping line 181302: expected 18 fields, saw 19\nSkipping line 194169: expected 18 fields, saw 19\nSkipping line 195290: expected 18 fields, saw 19\nSkipping line 205619: expected 18 fields, saw 19\nSkipping line 205620: expected 18 fields, saw 19\nSkipping line 205622: expected 18 fields, saw 19\nSkipping line 205631: expected 18 fields, saw 19\nSkipping line 205632: expected 18 fields, saw 19\nSkipping line 205634: expected 18 fields, saw 19\nSkipping line 205641: expected 18 fields, saw 19\nSkipping line 205642: expected 18 fields, saw 19\nSkipping line 205648: expected 18 fields, saw 19\nSkipping line 205651: expected 18 fields, saw 19\nSkipping line 205652: expected 18 fields, saw 19\nSkipping line 205656: expected 18 fields, saw 19\nSkipping line 205660: expected 18 fields, saw 19\nSkipping line 205661: expected 18 fields, saw 19\nSkipping line 205662: expected 18 fields, saw 19\nSkipping line 205664: expected 18 fields, saw 19\nSkipping line 205665: expected 18 fields, saw 19\nSkipping line 205680: expected 18 fields, saw 19\nSkipping line 205681: expected 18 fields, saw 19\nSkipping line 205713: expected 18 fields, saw 19\nSkipping line 205727: expected 18 fields, saw 19\nSkipping line 205731: expected 18 fields, saw 19\nSkipping line 205744: expected 18 fields, ...

# %%
#Coletando informações necessárias para os plots

# Tipos de aposentadorias apresentadas
tipo_aposentadoria = aposentados['Tipo aposentadoria'].value_counts()

# Selecionando apenas os registros de aposentadoria por invalidez
tipo_invalidez = aposentados.loc[aposentados['Tipo aposentadoria'] == 'APOSENTADORIA POR INVALIDEZ']

#Selecionando os Orgaos que tem aposentadoria por invalidez e contando sua ocorrencia
tipo_invalidez_orgao = tipo_invalidez['Orgao'].value_counts()

# Selecionando os 10 maiores valores para o plot
tipo_invalidez_orgao_maiores = tipo_invalidez_orgao.values[:9]
tipo_invalidez_orgao_maiores_index = tipo_invalidez_orgao.index[:9]

# %%
#Criando os gráficos
#Proporção de Tipos de Aposentadorias
plt.figure(figsize=(5,5))
plt.style.use('seaborn-pastel')
plt.title('Proporção de espécies')
explode = (0, 0.1, 0, 0)
plt.pie(x=tipo_aposentadoria.values,explode=explode,
        labels = tipo_aposentadoria.index, autopct='%1.2f%%')
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b77d2bb997cb> in <module>
#       1 #Criando os gráficos
#       2 #Proporção de Tipos de Aposentadorias
# ----> 3 plt.figure(figsize=(5,5))
#       4 plt.style.use('seaborn-pastel')
#       5 plt.title('Proporção de espécies')
#
# NameError: name 'plt' is not defined

# %%
#Grafico que apresenta a quantidade de aposentadoria por invalidez
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,5))
plt.bar(tipo_invalidez_orgao_maiores_index,tipo_invalidez_orgao_maiores)
plt.title('Proporção de Orgão com maior incidência de aposentadoria por invalidez')
plt.show()
