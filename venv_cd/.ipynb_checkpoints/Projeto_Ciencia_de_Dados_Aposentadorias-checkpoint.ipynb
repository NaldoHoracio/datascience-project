# %%
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read relative file: https://www.kaggle.com/rtatman/reproducibility-tips-absolute-vs-relative-paths
#df = pd.read_csv('C:/Users/maria/Documents/UFAL/Ciencia de dados/Projeto/data/APOSENTADOS_112020_FULL.csv',low_memory=False, error_bad_lines=False, sep=';')
df = pd.read_csv(r'../datasets/APOSENTADOS_112020_FULL.csv', sep=';', low_memory=False)
df.describe()
print("\n")
df.head()
# Out:
#                                                 Nome          CPF Matricula  \
# 0  ANTONIO ALVES BEZERRA                         ...  ***686441**   1,3E+11
# 1  ANTONIO CARLOS CONCEICAO MARTINS              ...  ***423941**   1,3E+11
# 2  ARLINDA COSTA GUTEMBERG                       ...  ***063691**   1,3E+11
# 3  BENTO MOREIRA LIMA JUNIOR                     ...  ***460301**   1,3E+11
# 4  BERENICE MOREIRA SANTOS                       ...  ***021701**   1,3E+11
#
#                                       Orgao Sigla Orgao  Orgao vinculacao  \
# 0  MINIST.DA AGRICULTURA,PECUARIA E ABAST.   MAPA                       0
# 1  MINIST.DA AGRICULTURA,PECUARIA E ABAST.   MAPA                       0
# 2  MINIST.DA AGRICULTURA,PECUARIA E ABAST.   MAPA                       0
# 3  MINIST.DA AGRICULTURA,PECUARIA E ABAST.   MAPA                       0
# 4  MINIST.DA AGRICULTURA,PECUARIA E ABAST.   MAPA                       0
#
#                               Cargo emprego Classe Padrao  Referencia  Nivel  \
# 0  AGENTE DE VIGILANCIA                          S    II            0      0
# 1  ESTATISTICO                                   S    III           0      0
# 2  AUXILIAR DE ENFERMAGEM                        S    III           0      0
# 3  AUDITOR FISCAL FEDERAL AGROPECUARIO           S    IV            0      0
# 4  AGENTE ADMINISTRATIVO                         S    III           0      0
#
#             Tipo aposentadoria                  Fund legal aposentadoria  \
# 0  VOLUNTARIA                   APOS. VOLUNTARIA C/PROVENTOS INTEGRAIS
# 1  VOLUNTARIA                   CF 40 III A
# 2  VOLUNTARIA                   APOS. VOLUNTARIA C/PROVENTOS INTEGRAIS
# 3  APOSENTADORIA POR INVALIDEZ  CF 40 I INT
# 4  VOLUNTARIA                   VOLUNTARIA (ART. 186 ITEM III ALINEA A)
#
#                               Portaria aposentadoria  \
# 0  PORTARIA NO. 63194 PUBLICADO EM 30DEZ1994     ...
# 1  PORTARIA NO. 26 PUBLICADO EM 31JAN1995        ...
# 2  PORTARIA NO. 341 PUBLICADO EM 01JUL1990       ...
# 3  LEI NO. 21050 PUBLICADO EM 02JUL1990          ...
# 4  PORTARIA NO. 253 PUBLICADO EM 31MAI1990       ...
#
#   Dt ocorrencia inatividade  \
# 0                  30121994
# 1                  31011995
# 2                   1071990
# 3                   2071990
# 4                  31051990
#
#                                      Nome ocorrencia  \
# 0  NOMEACAO PARA CARGO                           ...
# 1  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 2  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 3  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 4  NOMEACAO PARA CARGO                           ...
#
#   Dt ingresso servico publico  \
# 0                    15061962
# 1                    15061962
# 2                    15061962
# 3                     8061961
# 4                    21121961
#
#   Valor aposentadoria                                                                                                                                                              \
# 0                                           2.596,79
# 1                                          10.664,04
# 2                                           3.960,76
# 3                                          19.478,03
# 4                                           3.553,92
#
#   Unnamed: 18 Unnamed: 19
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
#Tratamento dos dados
#Drop colunas que não vão ser usadas
aposentados = df.drop(['Nome', 'CPF', 'Matricula', 'Sigla Orgao', 'Orgao vinculacao', 'Padrao',
        'Referencia', 'Nivel', 'Fund legal aposentadoria', 'Portaria aposentadoria'], axis=1)

# Tirando datas vazias
aposentados.drop(aposentados[aposentados['Dt ocorrencia inatividade'] == '        '].index, inplace = True)
aposentados.drop(aposentados[aposentados['Dt ingresso servico publico'] == '        '].index, inplace = True)

aposentados.head(5)
# Out:
#                                       Orgao  \
# 0  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 1  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 2  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 3  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 4  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
#
#                               Cargo emprego Classe  \
# 0  AGENTE DE VIGILANCIA                          S
# 1  ESTATISTICO                                   S
# 2  AUXILIAR DE ENFERMAGEM                        S
# 3  AUDITOR FISCAL FEDERAL AGROPECUARIO           S
# 4  AGENTE ADMINISTRATIVO                         S
#
#             Tipo aposentadoria Dt ocorrencia inatividade  \
# 0  VOLUNTARIA                                   30121994
# 1  VOLUNTARIA                                   31011995
# 2  VOLUNTARIA                                    1071990
# 3  APOSENTADORIA POR INVALIDEZ                   2071990
# 4  VOLUNTARIA                                   31051990
#
#                                      Nome ocorrencia  \
# 0  NOMEACAO PARA CARGO                           ...
# 1  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 2  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 3  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 4  NOMEACAO PARA CARGO                           ...
#
#   Dt ingresso servico publico  \
# 0                    15061962
# 1                    15061962
# 2                    15061962
# 3                     8061961
# 4                    21121961
#
#   Valor aposentadoria                                                                                                                                                              \
# 0                                           2.596,79
# 1                                          10.664,04
# 2                                           3.960,76
# 3                                          19.478,03
# 4                                           3.553,92
#
#   Unnamed: 18 Unnamed: 19
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
# Inserindo 0 nas datas com 7 dígitos
aposentados['Dt ocorrencia inatividade'] = aposentados['Dt ocorrencia inatividade'].str.zfill(8)
aposentados['Dt ingresso servico publico'] = aposentados['Dt ingresso servico publico'].str.zfill(8)
aposentados.head(5)
# Out:
#                                       Orgao  \
# 0  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 1  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 2  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 3  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 4  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
#
#                               Cargo emprego Classe  \
# 0  AGENTE DE VIGILANCIA                          S
# 1  ESTATISTICO                                   S
# 2  AUXILIAR DE ENFERMAGEM                        S
# 3  AUDITOR FISCAL FEDERAL AGROPECUARIO           S
# 4  AGENTE ADMINISTRATIVO                         S
#
#             Tipo aposentadoria Dt ocorrencia inatividade  \
# 0  VOLUNTARIA                                   30121994
# 1  VOLUNTARIA                                   31011995
# 2  VOLUNTARIA                                   01071990
# 3  APOSENTADORIA POR INVALIDEZ                  02071990
# 4  VOLUNTARIA                                   31051990
#
#                                      Nome ocorrencia  \
# 0  NOMEACAO PARA CARGO                           ...
# 1  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 2  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 3  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 4  NOMEACAO PARA CARGO                           ...
#
#   Dt ingresso servico publico  \
# 0                    15061962
# 1                    15061962
# 2                    15061962
# 3                    08061961
# 4                    21121961
#
#   Valor aposentadoria                                                                                                                                                              \
# 0                                           2.596,79
# 1                                          10.664,04
# 2                                           3.960,76
# 3                                          19.478,03
# 4                                           3.553,92
#
#   Unnamed: 18 Unnamed: 19
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
# Verificando quantas linhas das colunas de datas tem Nan
print(aposentados['Dt ocorrencia inatividade'].isnull().sum())
#print("\n")
print(aposentados['Dt ingresso servico publico'].isnull().sum())
# Out:
# 1
# 0

# %%
aposentados = aposentados[aposentados['Dt ocorrencia inatividade'].notna()]

aposentados = aposentados[aposentados['Dt ingresso servico publico'].notna()]

# %%
# Verificando quantas linhas das colunas de datas tem Nan
print(aposentados['Dt ocorrencia inatividade'].isnull().sum())
#print("\n")
print(aposentados['Dt ingresso servico publico'].isnull().sum())
aposentados.head(5)
# Out:
# 0
# 0
#                                       Orgao  \
# 0  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 1  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 2  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 3  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
# 4  MINIST.DA AGRICULTURA,PECUARIA E ABAST.
#
#                               Cargo emprego Classe  \
# 0  AGENTE DE VIGILANCIA                          S
# 1  ESTATISTICO                                   S
# 2  AUXILIAR DE ENFERMAGEM                        S
# 3  AUDITOR FISCAL FEDERAL AGROPECUARIO           S
# 4  AGENTE ADMINISTRATIVO                         S
#
#             Tipo aposentadoria Dt ocorrencia inatividade  \
# 0  VOLUNTARIA                                   30121994
# 1  VOLUNTARIA                                   31011995
# 2  VOLUNTARIA                                   01071990
# 3  APOSENTADORIA POR INVALIDEZ                  02071990
# 4  VOLUNTARIA                                   31051990
#
#                                      Nome ocorrencia  \
# 0  NOMEACAO PARA CARGO                           ...
# 1  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 2  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 3  ADMISSAO SEM CONCURSO PUBLICO                 ...
# 4  NOMEACAO PARA CARGO                           ...
#
#   Dt ingresso servico publico  \
# 0                    15061962
# 1                    15061962
# 2                    15061962
# 3                    08061961
# 4                    21121961
#
#   Valor aposentadoria                                                                                                                                                              \
# 0                                           2.596,79
# 1                                          10.664,04
# 2                                           3.960,76
# 3                                          19.478,03
# 4                                           3.553,92
#
#   Unnamed: 18 Unnamed: 19
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
# Remover string de data com len maior que 8
# https://stackoverflow.com/questions/13851535/how-to-delete-rows-from-a-pandas-dataframe-based-on-a-conditional-expression
aposentados = aposentados[aposentados['Dt ocorrencia inatividade'].map(len) <= 8]

aposentados = aposentados[aposentados['Dt ingresso servico publico'].map(len) <= 8]

# Analisar colunas de datas
print(aposentados['Dt ocorrencia inatividade'])
# Out:
# 0         30121994
# 1         31011995
# 2         01071990
# 3         02071990
# 4         31051990
#             ...
# 421558    18092015
# 421559    11121998
# 421560    21102015
# 421561    17012008
# 421562    10081976
# Name: Dt ocorrencia inatividade, Length: 413043, dtype: object

# %%
# Ordenando os valores para remover datas fora do padrão
aposentados = aposentados.sort_values(by=['Dt ocorrencia inatividade'], ascending=True)
aposentados.head(5)
# Out:
#                                            Orgao  \
# 172987  UNIVERSIDADE FEDERAL DO PARANA
# 46588   MINISTERIO DA SAUDE
# 68876   MINISTERIO DA SAUDE
# 68418   MINISTERIO DA SAUDE
# 319305  DEP.DE CENTRAL.SERV.DE INATIVOS E PENS.
#
#                                    Cargo emprego Classe  \
# 172987  GARCON                                        B
# 46588   AGENTE DE PORTARIA                            C
# 68876   AGENTE ADMINISTRATIVO                         S
# 68418   AGENTE ADMINISTRATIVO                         S
# 319305  MECANICO DE MOTOR A COMBUSTAO                 S
#
#                  Tipo aposentadoria Dt ocorrencia inatividade  \
# 172987  APOSENTADORIA POR INVALIDEZ                  00000005
# 46588   VOLUNTARIA                                   01011955
# 68876   APOSENTADORIA POR INVALIDEZ                  01011965
# 68418   APOSENTADORIA POR INVALIDEZ                  01011965
# 319305  VOLUNTARIA                                   01011967
#
#                                           Nome ocorrencia  \
# 172987                                     2006.
# 46588   NOMEACAO PARA CARGO                           ...
# 68876   ADMISSAO POR CONCURSO PUBLICO                 ...
# 68418   ADMISSAO POR CONCURSO PUBLICO                 ...
# 319305  ADMISSAO POR CONCURSO PUBLICO                 ...
#
#        Dt ingresso servico publico  \
# 172987                    04052006
# 46588                     01011950
# 68876                     01011955
# 68418                     01011955
# 319305                    30101954
#
#        Valor aposentadoria                                                                                                                                                              \
# 172987  ADMISSAO POR CONCURSO PUBLICO                 ...
# 46588                                            2.524,54
# 68876                                            3.189,65
# 68418                                            1.217,16
# 319305                                           3.378,10
#
#        Unnamed: 18 Unnamed: 19
# 172987    22111991    1.064,86
# 46588          NaN         NaN
# 68876          NaN         NaN
# 68418          NaN         NaN
# 319305         NaN         NaN

# %%
# Removendo valor discrepante
aposentados.drop(172987, inplace=True)
aposentados.head(5)
# Out:
#                                            Orgao  \
# 46588   MINISTERIO DA SAUDE
# 68876   MINISTERIO DA SAUDE
# 68418   MINISTERIO DA SAUDE
# 319305  DEP.DE CENTRAL.SERV.DE INATIVOS E PENS.
# 370220  FUND. INST. BRASIL. GEOG. E ESTATISTICA
#
#                                    Cargo emprego Classe  \
# 46588   AGENTE DE PORTARIA                            C
# 68876   AGENTE ADMINISTRATIVO                         S
# 68418   AGENTE ADMINISTRATIVO                         S
# 319305  MECANICO DE MOTOR A COMBUSTAO                 S
# 370220  TEC PLAN GEST INF INFOR GEOG ESTATIS          S
#
#                  Tipo aposentadoria Dt ocorrencia inatividade  \
# 46588   VOLUNTARIA                                   01011955
# 68876   APOSENTADORIA POR INVALIDEZ                  01011965
# 68418   APOSENTADORIA POR INVALIDEZ                  01011965
# 319305  VOLUNTARIA                                   01011967
# 370220  APOSENTADORIA POR INVALIDEZ                  01011968
#
#                                           Nome ocorrencia  \
# 46588   NOMEACAO PARA CARGO                           ...
# 68876   ADMISSAO POR CONCURSO PUBLICO                 ...
# 68418   ADMISSAO POR CONCURSO PUBLICO                 ...
# 319305  ADMISSAO POR CONCURSO PUBLICO                 ...
# 370220  ADMISSAO SEM CONCURSO PUBLICO                 ...
#
#        Dt ingresso servico publico  \
# 46588                     01011950
# 68876                     01011955
# 68418                     01011955
# 319305                    30101954
# 370220                    01061946
#
#        Valor aposentadoria                                                                                                                                                              \
# 46588                                            2.524,54
# 68876                                            3.189,65
# 68418                                            1.217,16
# 319305                                           3.378,10
# 370220                                           4.915,86
#
#        Unnamed: 18 Unnamed: 19
# 46588          NaN         NaN
# 68876          NaN         NaN
# 68418          NaN         NaN
# 319305         NaN         NaN
# 370220         NaN         NaN

# %%
# Ordenando os valores
aposentados = aposentados.sort_values(by=['Dt ingresso servico publico'], ascending=True)
aposentados.head(5)
# Out:
#                                            Orgao  \
# 325295  DEP.DE CENTRAL.SERV.DE INATIVOS E PENS.
# 317792  DEP.DE CENTRAL.SERV.DE INATIVOS E PENS.
# 23249   MINISTERIO DA ECONOMIA
# 318025  DEP.DE CENTRAL.SERV.DE INATIVOS E PENS.
# 318881  DEP.DE CENTRAL.SERV.DE INATIVOS E PENS.
#
#                                    Cargo emprego Classe  \
# 325295  AUX OPERAC DE SERV DIVERSOS                   B
# 317792  AGENTE SERVICOS ENGENHARIA                    S
# 23249   AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL      S
# 318025  AUX OPERAC DE SERV DIVERSOS                   B
# 318881  ARTIFICE DE MECANICA                          S
#
#                  Tipo aposentadoria Dt ocorrencia inatividade  \
# 325295  VOLUNTARIA                                   06111967
# 317792  VOLUNTARIA                                   02011993
# 23249   VOLUNTARIA                                   26061979
# 318025  VOLUNTARIA                                   01011993
# 318881  VOLUNTARIA                                   07031980
#
#                                           Nome ocorrencia  \
# 325295  ADMISSAO POR CONCURSO PUBLICO                 ...
# 317792  ADMISSAO POR CONCURSO PUBLICO                 ...
# 23249   ADMISSAO POR CONCURSO PUBLICO                 ...
# 318025  ADMISSAO POR CONCURSO PUBLICO                 ...
# 318881  ADMISSAO POR CONCURSO PUBLICO                 ...
#
#        Dt ingresso servico publico  \
# 325295                    01011932
# 317792                    01011936
# 23249                     01011937
# 318025                    01011938
# 318881                    01011938
#
#        Valor aposentadoria                                                                                                                                                              \
# 325295                                           4.039,27
# 317792                                           4.337,91
# 23249                                           24.508,93
# 318025                                           3.603,33
# 318881                                           4.920,03
#
#        Unnamed: 18 Unnamed: 19
# 325295         NaN         NaN
# 317792         NaN         NaN
# 23249          NaN         NaN
# 318025         NaN         NaN
# 318881         NaN         NaN

# %%
# Transformar data Dt ocorrencia inatividade; Dt ingresso servico publico; em tipo date %d%m%Y
aposentados['Dt ocorrencia inatividade'] = pd.to_datetime(aposentados['Dt ocorrencia inatividade'], format='%d%m%Y')
aposentados['Dt ingresso servico publico'] = pd.to_datetime(aposentados['Dt ingresso servico publico'],format='%d%m%Y')
aposentados.head(5)
# Out:
#                                            Orgao  \
# 325295  DEP.DE CENTRAL.SERV.DE INATIVOS E PENS.
# 317792  DEP.DE CENTRAL.SERV.DE INATIVOS E PENS.
# 23249   MINISTERIO DA ECONOMIA
# 318025  DEP.DE CENTRAL.SERV.DE INATIVOS E PENS.
# 318881  DEP.DE CENTRAL.SERV.DE INATIVOS E PENS.
#
#                                    Cargo emprego Classe  \
# 325295  AUX OPERAC DE SERV DIVERSOS                   B
# 317792  AGENTE SERVICOS ENGENHARIA                    S
# 23249   AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL      S
# 318025  AUX OPERAC DE SERV DIVERSOS                   B
# 318881  ARTIFICE DE MECANICA                          S
#
#                  Tipo aposentadoria Dt ocorrencia inatividade  \
# 325295  VOLUNTARIA                                 1967-11-06
# 317792  VOLUNTARIA                                 1993-01-02
# 23249   VOLUNTARIA                                 1979-06-26
# 318025  VOLUNTARIA                                 1993-01-01
# 318881  VOLUNTARIA                                 1980-03-07
#
#                                           Nome ocorrencia  \
# 325295  ADMISSAO POR CONCURSO PUBLICO                 ...
# 317792  ADMISSAO POR CONCURSO PUBLICO                 ...
# 23249   ADMISSAO POR CONCURSO PUBLICO                 ...
# 318025  ADMISSAO POR CONCURSO PUBLICO                 ...
# 318881  ADMISSAO POR CONCURSO PUBLICO                 ...
#
#        Dt ingresso servico publico  \
# 325295                  1932-01-01
# 317792                  1936-01-01
# 23249                   1937-01-01
# 318025                  1938-01-01
# 318881                  1938-01-01
#
#        Valor aposentadoria                                                                                                                                                              \
# 325295                                           4.039,27
# 317792                                           4.337,91
# 23249                                           24.508,93
# 318025                                           3.603,33
# 318881                                           4.920,03
#
#        Unnamed: 18 Unnamed: 19
# 325295         NaN         NaN
# 317792         NaN         NaN
# 23249          NaN         NaN
# 318025         NaN         NaN
# 318881         NaN         NaN

# %%
#Coletando informações necessárias para os plots

# Tipos de aposentadorias apresentadas
tipo_aposentadoria = aposentados['Tipo aposentadoria'].value_counts()

# Selecionando apenas os registros de aposentadoria por invalidez
tipo_invalidez = aposentados.loc[aposentados['Tipo aposentadoria'] == 'APOSENTADORIA POR INVALIDEZ']

# Selecionando os cargos que tem registro de aposentadoria por invalidez e
# que pertence ao orgão ministério da saúde
tipo_invalidez_orgao_cargos = aposentados.loc[aposentados['Orgao'] == 'MINISTERIO DA SAUDE                     ']

#Selecionando os tipos de cargos que tem no Ministerio da Saude que se aposentaram por invalidez
tipo_cargos_invalidez = tipo_invalidez_orgao_cargos['Cargo emprego'].value_counts()

#Selecionando os Orgaos que tem aposentadoria por invalidez e contando sua ocorrencia
tipo_invalidez_orgao = tipo_invalidez['Orgao'].value_counts()

# %%
#Seleciona os valores dos salários
# Criando os gráficos
# Proporção de Tipos de Aposentadorias
plt.figure(figsize=(10,5))
plt.style.use('seaborn-pastel')
plt.title('Proporção de Tipos de Aposentadoria', size=20)
explode = (0.1, 0, 0, 0.3)
plt.pie(tipo_aposentadoria.values,explode=explode, autopct='%1.2f%%')
plt.legend(labels = tipo_aposentadoria.index,title = "Tipo de Aposentadoria:")
plt.axis('equal')
plt.savefig('../imagens/tipos_aposentadoria.png', dpi=450, bbox_inches='tight');
plt.show()

# %%
# Grafico que apresenta a quantidade de aposentadoria por invalidez
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(15,8))
plt.barh(tipo_invalidez_orgao.index[:5],tipo_invalidez_orgao.values[:5])
plt.title('Proporção de Orgão com maior incidência de aposentadoria por invalidez', size=20)
plt.legend(title = "Tipo de Aposentadoria:",labels = tipo_invalidez_orgao.index[:5])
plt.xlabel('Ocorrência de Aposentadoria por invalidez', size=20)
plt.ylabel('-', size=20)
plt.savefig('../imagens/aposentadoria_invalidez.png', dpi=450, bbox_inches='tight');
plt.show()

# %%
# Grafico que apresenta os cargos e a quantidade de pessoas aposentadas por invalidez que trabalham no Ministerio da Saude
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(15,8))
plt.barh(tipo_cargos_invalidez.index[:5],tipo_cargos_invalidez.values[:5])
plt.title('Proporção de Orgão com maior incidência de aposentadoria por invalidez', size=20)
plt.legend(title = "Tipo de Aposentadoria:",labels = tipo_cargos_invalidez.index[:5])
plt.xlabel('Ocorrência de Aposentadoria por invalidez', size=20)
plt.ylabel('Cargo', size=20)
plt.savefig('../imagens/maior_incidencia_invalidez.png', dpi=450, bbox_inches='tight')
plt.show()
